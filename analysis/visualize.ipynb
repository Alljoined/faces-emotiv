# %%
import mne

filePath = r"C:\Users\HP\Documents\faces-emotiv\recordings\subj_1\session_1\block_2\Subject 1, Session 1, Block 2 Recording_EPOCFLEX_213075_2024.08.05T16.00.46.04.00.md.edf"
raw = mne.io.read_raw_edf(filePath, preload=True)
# Out:
# Extracting EDF parameters from C:\Users\HP\Documents\faces-emotiv\recordings\subj_1\session_1\block_2\Subject 1, Session 1, Block 2 Recording_EPOCFLEX_213075_2024.08.05T16.00.46.04.00.md.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 895  =      0.000 ...     6.992 secs...

# %%
raw.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: TimestampS, TimestampMs, Counter, Interpolated, T7, TP7, CP5, ...
#  chs: 123 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 64.0 Hz
#  meas_date: 2024-08-05 16:00:46 UTC
#  nchan: 123
#  projs: []
#  sfreq: 128.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 1908x800 with 4 Axes>
# <MNEBrowseFigure size 1908x800 with 4 Axes>

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os
import numpy as np

index = 6
imgPath = os.path.join("..\\stimulus", '{:04}.png'.format(index))

print(imgPath)
image = Image.open(imgPath)

# Convert the image to a numpy array
image_array = np.array(image)

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# ..\stimulus\0006.png

# %%
image_array.shape
# Out:
# (656, 875, 3)
